# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from apiclient.discovery import build
import pandas as pd
# Data to be stored
category = []
no_of_samples = 5000

# Gathering Data using the Youtube API
api_key = "AIzaSyAbvHOWfQnTjPPOrjxykFcgXU7JX51gQyw"
youtube_api = build('youtube','v3', developerKey = api_key)

# Travel Data
vaping_titles = []
vaping_descriptions = []
vaping_ids = []

req = youtube_api.search().list(q='vaping', part='snippet', type='video', maxResults = 50)
res = req.execute()
while(len(vaping_titles)<no_of_samples):
    for i in range(len(res['items'])):
        vaping_titles.append(res['items'][i]['snippet']['title'])
        vaping_descriptions.append(res['items'][i]['snippet']['description'])
        vaping_ids.append(res['items'][i]['id']['videoId'])
        category.append('social_evil')
            
    if('nextPageToken' in res):
        next_page_token = res['nextPageToken']
        req = youtube_api.search().list(q='vaping addiction', part='snippet', type='video', maxResults = 50, pageToken=next_page_token)
        res = req.execute()
    else:
        break

# Construct Dataset
final_titles = vaping_titles
final_descriptions = vaping_descriptions
final_ids = vaping_ids
data = pd.DataFrame({'Video Id': final_ids, 'Title': final_titles, 'Description': final_descriptions, 'Category': category}) 
data.to_csv('/content/gdrive/My Drive/vaping.csv')
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-31-d3e5bf579aea> in <module>()
#      26         next_page_token = res['nextPageToken']
#      27         req = youtube_api.search().list(q='vaping addiction', part='snippet', type='video', maxResults = 50, pageToken=next_page_token)
# ---> 28         res = req.execute()
#      29     else:
#      30         break
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     896             callback(resp)
# ...
